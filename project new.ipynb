# %% [markdown]
# #Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Pandas Library

# %%
salary_data = pd.read_csv("Salary_Data.csv")

# %%
salary_data.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
print(salary_data)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
salary_data.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
salary_data.describe
# Out:
# <bound method NDFrame.describe of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
salary_data.shape
# Out:
# (30, 2)

# %%
salary_data.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
salary_data.dropna(subset=['Salary'], inplace=True)

# %%
salary_data.drop_duplicates(inplace=True)

# %%
salary_data.plot('Salary')
# Out:
# <Axes: xlabel='Salary'>

# %% [raw]
# #Data Visualization using Matplotlib

# %%
plt.plot(salary_data['Salary'], color = 'red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.hist(salary_data['Salary'],bins = 10, color = 'Green')
plt.xlabel('Salary')
plt.ylabel('YearsExperience')
plt.show()

# %%
plt.xlabel('Salary')
plt.ylabel('YearsExperience')
plt.title('Scatter plot')
plt.scatter(x=salary_data['Salary'],y=salary_data['YearsExperience'], color ='Orange')

# %%
sns.histplot(data=salary_data, x='Salary', bins=20, kde=True, color = 'blue')
plt.xlabel('Salary')
plt.ylabel('YearsExperience')
plt.title('Salary Distribution')
plt.show()

# %%
sns.scatterplot(data=salary_data, x='YearsExperience', y='Salary', color = 'Black')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Salary vs. Years of Experience')
plt.legend(['Regression'])
plt.plot(X, model.predict(X), color='red', linewidth=2)
plt.show()

# %% [markdown]
# #Seaborn Library

# %%
correlation_matrix = salary_data.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
salary_comparison = salary_data.groupby('YearsExperience')['Salary'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(data=salary_data, x='YearsExperience', y='Salary')
plt.xlabel('Experience')
plt.ylabel('Average Salary')
plt.title('Average Salary by Experience')
plt.show()

# %% [markdown]
# #Sklearn Library

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
X = salary_data[['YearsExperience']]
y = salary_data['Salary']
model.fit(X, y)
slope = model.coef_[0]
intercept = model.intercept_

# %%
print(f"Slope (Coefficient): {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
# Out:
# Slope (Coefficient): 9449.96
# Intercept: 25792.20

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
new_experience = 5
predicted_salary = model.predict([[new_experience]])

# %%
print(f"Predicted Salary for {new_experience} years of experience: {predicted_salary[0]:,.2f}")
# Out:
# Predicted Salary for 5 years of experience: 73,042.01

# %% [markdown]
# #Above mentioned are some example of Data Analysis and Data Visualization using Python Libraries on a Salary Dataset
